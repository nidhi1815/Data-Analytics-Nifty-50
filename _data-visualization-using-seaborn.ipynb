# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
file_path = r"C:\Users\nidhi\OneDrive\Desktop\projects\DA\Toyota.csv.csv"
cars_data = pd.read_csv(file_path)
sns.set( style='darkgrid')
sns.regplot( x=cars_data['Age'] , y=cars_data['Price']) #regression plot
# Out:
# <Axes: xlabel='Age', ylabel='Price'>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

file_path = r"C:\Users\nidhi\OneDrive\Desktop\projects\DA\Toyota.csv.csv"
cars_data = pd.read_csv(file_path)
sns.countplot(x='FuelType' , data=cars_data)
# Out:
# <Axes: xlabel='FuelType', ylabel='count'>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

file_path = r"C:\Users\nidhi\OneDrive\Desktop\projects\DA\Toyota.csv.csv"
cars_data = pd.read_csv(file_path)
sns.countplot(x='FuelType',data=cars_data, hue='Automatic')
# Out:
# <Axes: xlabel='FuelType', ylabel='count'>

# %%
#box-plot
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

file_path = r"C:\Users\nidhi\OneDrive\Desktop\projects\DA\Toyota.csv.csv"
cars_data = pd.read_csv(file_path)
sns.boxplot( y=cars_data['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
cars_data.mean()
# Out:
# C:\Users\nidhi\AppData\Local\Temp\ipykernel_24080\2747742096.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cars_data.mean()
# Price        10730.824513
# Age             55.947075
# KM           68533.259749
# HP             101.502089
# MetColor         0.674791
# Automatic        0.055710
# CC            1566.827994
# Doors            4.033426
# Weight        1072.459610
# dtype: float64

# %%
import seaborn as sns
sns.boxplot(x=cars_data['FuelType'], y=cars_data['Price'])
# Out:
# <Axes: xlabel='FuelType', ylabel='Price'>

# %%
sns.boxplot(x=cars_data['FuelType'], y=cars_data['Price'],hue='Automatic', data= cars_data)
# Out:
# <Axes: xlabel='FuelType', ylabel='Price'>

# %%
import seaborn as sns
import pandas as pd
import numpy as np

#create a dataset
df = pd.DataFrame(np.random.random((5,5)), columns=["a","b","c","d","e"])  # Corrected the capitalization of DataFrame

#default heatmap
p1 = sns.heatmap(df)

# %%
#pair-plot
sns.pairplot(cars_data, kind = 'scatter',hue='FuelType')
plt.show()
